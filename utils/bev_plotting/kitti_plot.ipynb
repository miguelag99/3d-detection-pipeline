# %%
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from utils import plot_bird_view

# %%
# Read gt and detection file
im_id = 3
annotation_header = ['type','truncated','occluded','alpha','left','top','right','bottom','h','w','l','x','y','z','rot_y','score']
det_fd = pd.read_csv(f'/home/robesafe/Miguel/3d-detection-pipeline/results/geometric_estimation/{im_id:06}.txt',names=annotation_header, sep=' ')
gt_fd = pd.read_csv(f'/media/robesafe/SSD_SATA/KITTI_DATASET/label_2/{im_id:06}.txt',names=annotation_header, sep=' ')

# %%
# Define bev limits
x_max = 30
z_max = 50
pix_x = 1000
pix_z = 2000
im = np.zeros((pix_z,pix_x,3))
cv2.circle(im, (int(pix_x/2),int(pix_z)), 4, (255,0,0), thickness=5)
pass
# plt.imshow(im)

# %%
for idx,row in gt_fd.iterrows():
    
    plot_bird_view(im,(row['h'],row['w'],row['l']),row['alpha'],row['rot_y']-row['alpha'],(row['x'],row['y'],row['z']),(0,255,0),x_max,z_max)

for idx,row in det_fd.iterrows():
    
    plot_bird_view(im,(row['h'],row['w'],row['l']),row['alpha'],row['rot_y']-row['alpha'],(row['x'],row['y'],row['z']),(255,0,0),x_max,z_max)

plt.imshow(im)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Processing object in (1.0, 1.75, 13.22)
#
# Processing object in (0.97, 1.65, 10.34)
#
# Processing object in (-4.0, 1.65, 5.89)
#
# Processing object in (-4.7, 1.65, 6.13)
#
# Processing object in (-5.11, 1.65, 6.33)
#
# Processing object in (-7.11, 1.65, 9.01)
#
# Processing object in (0.63, 1.65, 8.2)
#
# Processing object in (-5.34, 1.65, 6.47)
#
# Processing object in (-6.33, 1.65, 8.68)
#
# Processing object in (-7.46, 1.65, 9.15)
#
# Processing object in (-4.27, 1.65, 6.3)
#
# Processing object in (-4.79, 1.65, 5.89)
#
# Processing object in (-5.0, 1.65, 6.04)
#
# Processing object in (-3.93, 1.65, 5.89)
#
# Processing object in (-3.53, 1.65, 5.92)
#
# Processing object in (-8.46, 1.65, 10.62)
#
# Processing object in (5.87, 1.65, -7.94)
#
# Processing object in (6.46, 1.65, 7.53)
#
# Processing object in (-4.63, 1.65, 5.89)
#
# Processing object in (-7.54, 1.65, 10.25)
#
# Processing object in (5.91, 1.65, 7.0)
#
# Processing object in (-0.88, 1.65, 5.89)
#
# Processing object in (7.69, 1.65, 9.15)
#
# Processing object in (5.52, 1.65, 6.83)
#
# Processing object in (-9.37, 1.65, 11.33)
#
# Processing object in (4.87, 1.65, 5.89)
#
# Processing object in (9.96, 1.65, 13.5)
#
# Processing object in (4.56, 1.65, 5.89)
#
# Processing object in (-5.16, 1.65, 7.39)
#
# Processing object in (-6.21, 1.65, 7.88)
#
# Processing object in (-3.76, 1.65, 5.89)
#
# Processing object in (11.64, 1.65, 13.66)
#
# Processing object in (-11.62, 1.65, 13.99)
#
# Processing object in (11.62, 1.65, 13.5)
#
# Processing object in (-4.22, 1.65, -9.38)
#
# Processing object in (5.0, 1.65, 5.89)
#
# Processing object in (0.49, 1.65, -8.39)
#
# Processing object in (0.77, 1.65, 20.13)
#
# Processing object in (-3.75, 1.65, 5.89)
#
# Processing object in (-6.47, 1.65, -8.7)
#
# Processing object in (-4.62, 1.65, 6.8)
#
# Processing object in (4.52, 1.65, 5.89)
#
# Processing object in (-4.34, 1.65, 5.89)
#
# Processing object in (1.41, 1.65, 19.47)
#
# Processing object in (8.61, 1.65, 10.61)
#
# Processing object in (6.1, 1.65, -7.59)
#
# Processing object in (38.82, 1.65, -70.61)
#
# Processing object in (0.71, 1.65, 13.51)
#
# Processing object in (-8.7, 1.65, -10.28)
#
# Processing object in (-48.24, 1.65, -63.18)
#
# Processing object in (0.17, 1.65, 16.06)
#
# Processing object in (-1.42, 1.65, 5.89)
#
# Processing object in (-4.74, 1.65, 5.89)
#
# Processing object in (7.58, 1.65, -9.31)
#
# Processing object in (0.89, 1.65, -8.7)
#
# Processing object in (-7.23, 1.65, 9.59)
#
# Processing object in (11.28, 1.65, -13.71)
#
# Processing object in (6.15, 1.65, 7.43)
#
# Processing object in (163.04, 1.65, 193.25)
#
# Processing object in (-6.27, 1.65, -7.74)
#
# Processing object in (3.39, 1.65, 5.89)
#
# Processing object in (-3.49, 1.65, 5.89)
#
# Processing object in (-8.87, 1.65, 10.81)
#
# Processing object in (5.19, 1.65, 6.04)
#
# Processing object in (-7.76, 1.65, -9.03)
#
# Processing object in (14.1, 1.65, 20.47)
#
# Processing object in (-1.68, 1.65, 5.89)
#
# Processing object in (-6.57, 1.65, -10.19)
#
# Processing object in (-7.01, 1.65, -9.93)
#
# Processing object in (15.15, 1.65, 17.99)
#
# Processing object in (3.55, 1.65, -16.57)
#
# Processing object in (4.82, 1.65, 5.89)
#
# Processing object in (-4.08, 1.65, 5.89)
#
# Processing object in (2.79, 1.65, 6.16)
#
# Processing object in (-4.39, 1.65, 5.89)
#
# Processing object in (11.39, 1.65, -14.37)
#
# Processing object in (-4.9, 1.65, -10.02)
#
# Processing object in (-4.91, 1.65, 5.89)
#
# Processing object in (-6.57, 1.65, -7.64)
#
# Processing object in (0.41, 1.65, 23.28)
#
# Processing object in (20.45, 1.65, 23.73)
#
# Processing object in (-4.77, 1.65, 5.89)
#
# Processing object in (2.29, 1.65, 15.43)
#
# Processing object in (3.96, 1.65, 5.89)
#
# Processing object in (-2.2, 1.65, -7.09)
#
# Processing object in (-4.91, 1.65, 5.89)
#
# Processing object in (4.26, 1.65, 5.89)
#
# Processing object in (-0.13, 1.65, 5.89)
#
# Processing object in (-11.73, 1.65, -14.37)
#
# Processing object in (7.31, 1.65, -9.24)
#
# Processing object in (-4.01, 1.65, 6.07)
#
# Processing object in (-3.39, 1.65, 5.89)
#
# Processing object in (-4.3, 1.65, 5.89)
#
# Processing object in (-0.04, 1.65, -8.28)
#
# Processing object in (1.59, 1.65, 10.81)
#
# Processing object in (-5.81, 1.65, -6.89)
#
# Processing object in (16.95, 1.65, -20.94)
#
# Processing object in (5.07, 1.65, 5.89)
#
# Processing object in (-4.6, 1.65, -9.1)
#
# Processing object in (0.62, 1.65, 7.48)
#
# Processing object in (-5.76, 1.65, -6.93)
#
# Processing object in (-2.19, 1.65, 5.89)
#
# Processing object in (0.89, 1.65, 27.59)
#
# Processing object in (-4.53, 1.65, -8.83)
#
# Processing object in (-1.79, 1.65, 5.89)
#
# Processing object in (7.02, 1.65, -75.09)
#
# Processing object in (13.86, 1.65, 16.73)
#
# Processing object in (5.94, 1.65, 7.67)
#
# Processing object in (-7.14, 1.65, -12.82)
#
# Processing object in (1.39, 1.65, -12.17)
#
# Processing object in (7.96, 1.65, 9.29)
#
# Processing object in (-163.02, 1.65, -418.1)
#
# Processing object in (2.44, 1.65, 22.4)
#
# Processing object in (-0.68, 1.65, 5.89)
#
# Processing object in (0.71, 1.65, -9.39)
#
# Processing object in (31.7, 1.65, 38.2)
#
# Processing object in (22.97, 1.65, 37.02)
#
# Processing object in (-1.45, 1.65, 5.89)
#
# Processing object in (-4.6, 1.65, 5.89)
#
# Processing object in (-9.23, 1.65, 11.43)
#
# Processing object in (-6.23, 1.65, -10.02)
#
# Processing object in (-3.71, 1.65, -8.28)
#
# Processing object in (-22.48, 1.65, 27.6)
#
# Processing object in (3.35, 1.65, 5.95)
#
# Processing object in (15.3, 1.65, 24.22)
#
# Processing object in (-0.74, 1.65, 5.89)
#
# Processing object in (-0.27, 1.65, -10.28)
#
# Processing object in (-2.68, 1.65, -44.34)
#
# Processing object in (-51.92, 1.65, 62.23)
#
# Processing object in (5.53, 1.65, -6.89)
#
# Processing object in (-4.89, 1.65, 5.89)
#
# Processing object in (-6.56, 1.65, 9.59)
#
# Processing object in (0.06, 1.65, 5.89)
#
# Processing object in (0.37, 1.65, 15.23)
#
# Processing object in (2.78, 1.65, 5.89)
#
# Processing object in (-10.65, 1.65, -12.68)
#
# Processing object in (-1.66, 1.65, 25.8)
#
# Processing object in (-8.21, 1.65, 11.01)
#
# Processing object in (20.78, 1.65, 24.21)
#
# Processing object in (10.01, 1.65, -12.04)
#
# Processing object in (-17.06, 1.65, 20.48)
#
# Processing object in (20.55, 1.65, 24.72)
#
# Processing object in (-0.5, 1.65, -14.72)
#
# Processing object in (-4.67, 1.65, 5.89)
#
# Processing object in (1.4, 1.65, 5.92)
#
# Processing object in (1.32, 1.65, 9.99)
#
# Processing object in (-5.42, 1.65, -17.81)
#
# Processing object in (-4.85, 1.65, 5.89)
#
# Processing object in (-5.05, 1.65, -17.55)
#
# Processing object in (-2.14, 1.65, -6.97)
#
# Processing object in (-3.89, 1.65, 6.33)
#
# Processing object in (-2.24, 1.65, -7.4)
#
# Processing object in (3.31, 1.65, 6.04)
#
# Processing object in (-0.77, 1.65, 6.07)
#
# Processing object in (19.92, 1.65, -25.96)
#
# Processing object in (25.73, 1.65, 30.4)
#
# Processing object in (-1.78, 1.65, 6.01)
#
# Processing object in (-4.59, 1.65, 6.16)
#
# Processing object in (21.95, 1.65, 27.58)
#
# Processing object in (1.06, 1.65, 5.89)
#
# Processing object in (-0.7, 1.65, 5.89)
#
# Processing object in (3.0, 1.65, 19.79)
#
# Processing object in (-3.28, 1.65, 5.95)
#
# Processing object in (4.61, 1.65, 5.89)
#
# Processing object in (-3.04, 1.65, 5.89)
#
# Processing object in (5.08, 1.65, 5.89)
#
# Processing object in (-38.7, 1.65, 47.37)
#
# Processing object in (-18.6, 1.65, 23.75)
#
# Processing object in (-36.75, 1.65, -42.76)
#
# Processing object in (-6.08, 1.65, -7.09)
#
# Processing object in (-4.75, 1.65, -15.91)
#
# Processing object in (19.05, 1.65, 29.64)
#
# Processing object in (-8.79, 1.65, -11.35)
#
# Processing object in (37.76, 1.65, 43.83)
#
# Processing object in (-5.66, 1.65, -9.93)
#
# Processing object in (1.87, 1.65, 6.1)
#
# Processing object in (-4.28, 1.65, 6.96)
#
# Processing object in (0.78, 1.65, 5.89)
#
# Processing object in (3.7, 1.65, -8.11)
#
# Processing object in (4.1, 1.65, -20.94)
#
# Processing object in (25.6, 1.65, -92.6)
#
# Processing object in (-1.83, 1.65, 15.84)
#
# Processing object in (-5.19, 1.65, 7.39)
#
# Processing object in (5.09, 1.65, -8.76)
#
# Processing object in (1.82, 1.65, 16.28)
#
# Processing object in (-4.53, 1.65, -10.19)
#
# Processing object in (1.88, 1.65, -9.46)
#
# Processing object in (0.17, 1.65, 9.36)
#
# Processing object in (-1.07, 1.65, -7.94)
#
# Processing object in (-4.3, 1.65, 5.89)
#
# Processing object in (-3.28, 1.65, 5.89)
#
# Processing object in (0.47, 1.65, 5.95)
#
# Processing object in (6.53, 1.65, -17.55)
#
# Processing object in (2.98, 1.65, 5.89)
#
# Processing object in (4.97, 1.65, 5.89)
#
# Processing object in (2.95, 1.65, 6.2)
#
# Processing object in (3.94, 1.65, 8.62)
#
# Processing object in (0.17, 1.65, 25.8)
#
# Processing object in (6.19, 1.65, 8.32)
#
# Processing object in (1.06, 1.65, 24.22)
#
# Processing object in (3.01, 1.65, 5.89)
#
# Processing object in (3.14, 1.65, 6.26)
#
# Processing object in (-6.09, 1.65, -19.89)
#
# Processing object in (3.69, 1.65, 19.16)
#
# Processing object in (-0.46, 1.65, 6.1)
#
# Processing object in (-7.01, 1.65, 11.43)
#
# Processing object in (4.24, 1.65, 27.59)
#
# Processing object in (344.45, 1.65, 1033.51)
#
# Processing object in (-1.64, 1.65, 5.98)
#
# Processing object in (2.88, 1.65, 14.85)
#
# Processing object in (89.0, 1.65, 166.38)
#
# Processing object in (4.33, 1.65, -22.11)
#
# Processing object in (-3.25, 1.65, -12.55)
#
# Processing object in (0.06, 1.65, 6.01)
#
# Processing object in (4.89, 1.65, 5.89)
#
# Processing object in (30.31, 1.65, 73.7)
#
# Processing object in (-0.02, 1.65, 8.56)
#
# Processing object in (3.66, 1.65, 5.89)
#
# Processing object in (-2.0, 1.65, 5.98)
#
# Processing object in (-1.87, 1.65, 106.81)
#
# Processing object in (-1.02, 1.65, 25.8)
#
# Processing object in (-8.01, 1.65, -9.69)
#
# Processing object in (3.21, 1.65, 5.89)
#
# Processing object in (-7.33, 1.65, -26.54)
#
# Processing object in (3.01, 1.65, 5.89)
#
# Processing object in (-5.87, 1.65, -8.39)
#
# Processing object in (0.97, 1.65, -9.24)
#
# Processing object in (11.06, 1.65, 16.73)
#
# Processing object in (-235.44, 1.65, -1399.45)
#
# Processing object in (2.86, 1.65, 14.85)
#
# Processing object in (-1.5, 1.65, 5.95)
#
# Processing object in (-35.36, 1.65, -66.71)
#
# Processing object in (-3.1, 1.65, -10.37)
#
# Processing object in (5.98, 1.65, 69.43)
#
# Processing object in (-6.74, 1.65, -14.37)
#
# Processing object in (10.88, 1.65, 16.73)
#
# Processing object in (2.35, 1.65, -8.39)
#
# Processing object in (0.29, 1.65, 5.89)
#
# Processing object in (5.7, 1.65, -6.89)
#
# Processing object in (-0.43, 1.65, 24.73)
#
# Processing object in (5.76, 1.65, -26.54)
#
# Processing object in (-4.05, 1.65, -10.84)
#
# Processing object in (4.9, 1.65, 5.89)
#
# Processing object in (0.29, 1.65, 6.47)
#
# Processing object in (-1.61, 1.65, 5.89)
#
# Processing object in (39.98, 1.65, -47.88)
#
# Processing object in (-2.7, 1.65, 9.83)
#
# Processing object in (2.89, 1.65, 25.25)
#
# Processing object in (-3.92, 1.65, 5.89)
#
# Processing object in (76.5, 1.65, 90.45)
#
# Processing object in (0.24, 1.65, 11.01)
#
# Processing object in (-2.83, 1.65, 5.89)
#
# Processing object in (-13.46, 1.65, 16.51)
#
# Processing object in (5.59, 1.65, 8.14)
#
# Processing object in (-23.31, 1.65, -35.17)
#
# Processing object in (-3.58, 1.65, -100.44)
#
# Processing object in (-1.73, 1.65, -7.05)
#
# Processing object in (-0.62, 1.65, 42.3)
#
# Processing object in (19.53, 1.65, 32.04)
#
# Processing object in (7.89, 1.65, -11.8)
#
# Processing object in (4.36, 1.65, 28.24)
#
# Processing object in (6.47, 1.65, -20.58)
#
# Processing object in (-4.27, 1.65, 7.39)
#
# Processing object in (4.19, 1.65, 5.89)
#
# Processing object in (24.39, 1.65, 56.28)
#
# Processing object in (-15.98, 1.65, -18.65)
#
# Processing object in (0.76, 1.65, 6.72)
#
# Processing object in (10.85, 1.65, -15.1)
#
# Processing object in (10.71, 1.65, 13.98)
#
# Processing object in (-0.45, 1.65, 5.89)
#
# Processing object in (-0.93, 1.65, 5.89)
#
# Processing object in (-3.25, 1.65, 5.89)
#
# Processing object in (0.28, 1.65, 5.89)
#
# Processing object in (-2.33, 1.65, 24.73)
#
# Processing object in (15.46, 1.65, -28.44)
#
# Processing object in (5.55, 1.65, -12.29)
#
# Processing object in (18.12, 1.65, 26.36)
#
# Processing object in (8.11, 1.65, 17.21)
#
# Processing object in (-4.14, 1.65, 5.89)
#
# Processing object in (1.27, 1.65, 14.85)
#
# Processing object in (-0.59, 1.65, 5.92)
#
# Processing object in (0.31, 1.65, 42.3)
#
# Processing object in (20.69, 1.65, 69.41)
#
# Processing object in (1.05, 1.65, 26.37)
#
# Processing object in (-3.77, 1.65, 5.89)
#
# Processing object in (-1.9, 1.65, 24.22)
#
# Processing object in (1.63, 1.65, 22.4)
#
# Processing object in (2.0, 1.65, 5.89)
#
# Processing object in (-9.21, 1.65, 11.11)
#
# Processing object in (-1.62, 1.65, 43.86)
#
# Processing object in (0.66, 1.65, 5.89)
#
# Processing object in (3.27, 1.65, 27.59)
#
# Processing object in (-1.7, 1.65, 28.25)
#
# Processing object in (4.0, 1.65, -19.56)
#
# Processing object in (8.93, 1.65, 11.54)
#
# Processing object in (1.67, 1.65, 9.67)
#
# Processing object in (5.18, 1.65, 18.0)
#
# Processing object in (16.88, 1.65, 22.39)
#
# Processing object in (-4.1, 1.65, 8.94)
#
# Processing object in (0.17, 1.65, 6.04)
#
# Processing object in (7.8, 1.65, -9.39)
#
# Processing object in (3.39, 1.65, 6.29)
#
# Processing object in (3.7, 1.65, 21.2)
#
# Processing object in (-0.37, 1.65, 16.97)
#
# Processing object in (-5.5, 1.65, -19.89)
#
# Processing object in (-6.34, 1.65, -20.23)
#
# Processing object in (15.47, 1.65, 40.84)
#
# Processing object in (-6.93, 1.65, -13.55)
#
# Processing object in (-15.61, 1.65, 35.93)
#
# Processing object in (-0.84, 1.65, 5.89)
#
# Processing object in (4.76, 1.65, 19.15)
#
# Processing object in (-0.99, 1.65, 26.97)
#
# Processing object in (-25.73, 1.65, -41.27)
#
# Processing object in (3.57, 1.65, 14.67)
#
# Processing object in (5.72, 1.65, 9.08)
#
# Processing object in (3.43, 1.65, 5.89)
#
# Processing object in (9.27, 1.65, 12.78)
#
# Processing object in (19.7, 1.65, -36.23)
#
# Processing object in (-5.8, 1.65, 26.97)
#
# Processing object in (-9.43, 1.65, -34.16)
#
# Processing object in (5.95, 1.65, 43.85)
#
# Processing object in (-14.17, 1.65, -21.32)
#
# Processing object in (-5.22, 1.65, -7.31)
#
# Processing object in (-60.4, 1.65, 73.8)
#
# Processing object in (4.47, 1.65, 5.89)
#
# Processing object in (8.77, 1.65, 30.41)
#
# Processing object in (-4.54, 1.65, 5.89)
#
# Processing object in (-7.51, 1.65, -15.29)
#
# Processing object in (0.03, 1.65, 30.41)
#
# Processing object in (7.8, 1.65, 23.27)
#
# Processing object in (-7.29, 1.65, -14.03)
#
# Processing object in (-0.56, 1.65, 5.89)
#
# Processing object in (3.63, 1.65, -12.04)
#
# Processing object in (-873.17, 1.65, 1050.13)
#
# Processing object in (-2.57, 1.65, -21.7)
#
# Processing object in (-101.07, 1.65, 146.34)
#
# Processing object in (-7.99, 1.65, 12.26)
#
# Processing object in (-0.23, 1.65, -9.77)
#
# Processing object in (6.94, 1.65, -16.12)
#
# Processing object in (4.5, 1.65, 9.36)
#
# Processing object in (-22.36, 1.65, -26.55)
#
# Processing object in (-21.09, 1.65, -29.15)
#
# Processing object in (-6.66, 1.65, -15.1)
#
# Processing object in (514.34, 1.65, -638.18)
#
# Processing object in (-0.31, 1.65, 6.04)
#
# Processing object in (11.25, 1.65, 20.12)
#
# Processing object in (-4.66, 1.65, -12.17)
#
# Processing object in (-1.91, 1.65, 5.89)
#
# Processing object in (44.05, 1.65, -80.11)
#
# Processing object in (-1.86, 1.65, -6.97)
#
# Processing object in (0.52, 1.65, 9.22)
#
# Processing object in (-6.48, 1.65, 166.6)
#
# Processing object in (2.51, 1.65, 10.08)
#
# Processing object in (-8.72, 1.65, -17.04)
#
# Processing object in (-4.15, 1.65, 5.89)
#
# Processing object in (1.46, 1.65, 5.89)
#
# Processing object in (6.83, 1.65, 43.85)
#
# Processing object in (1.26, 1.65, -13.25)
#
# Processing object in (5.48, 1.65, -10.1)
#
# Processing object in (4.8, 1.65, 22.4)
#
# Processing object in (-3.19, 1.65, -7.22)
#
# Processing object in (0.59, 1.65, 98.01)
#
# Processing object in (4.35, 1.65, 24.72)
#
# Processing object in (-13.59, 1.65, -26.55)
#
# Processing object in (5.02, 1.65, 43.85)
#
# Processing object in (6.45, 1.65, 21.59)
#
# Processing object in (-4.13, 1.65, 5.89)
#
# Processing object in (24.27, 1.65, -29.14)
#
# Processing object in (6.99, 1.65, -11.25)
#
# Processing object in (14.41, 1.65, -42.74)
#
# Processing object in (0.36, 1.65, -10.64)
#
# Processing object in (26.06, 1.65, -31.44)
#
# Processing object in (-1.07, 1.65, 69.43)
#
# Processing object in (-0.25, 1.65, 5.89)
#
# Processing object in (10.17, 1.65, -20.94)
#
# Processing object in (-3.27, 1.65, 5.89)
#
# Processing object in (-6.14, 1.65, -12.55)
#
# Processing object in (-10.16, 1.65, 13.21)
#
# Processing object in (7.68, 1.65, 43.85)
#
# Processing object in (0.94, 1.65, 5.89)
#
# Processing object in (0.69, 1.65, -8.51)
#
# Processing object in (9.37, 1.65, 25.25)
#
# Processing object in (6.19, 1.65, -8.96)
#
# Processing object in (4.18, 1.65, 5.89)
#
# Processing object in (20.51, 1.65, -29.14)
#
# Processing object in (24.4, 1.65, -44.32)
#
# Processing object in (2.45, 1.65, 6.01)
#
# Processing object in (7.0, 1.65, 24.22)
#
# Processing object in (0.05, 1.65, 6.5)
#
# Processing object in (-2.84, 1.65, 28.25)
#
# Processing object in (-4.08, 1.65, -14.37)
#
# Processing object in (-0.3, 1.65, 6.88)
#
# Processing object in (4.86, 1.65, -21.31)
#
# Processing object in (3.06, 1.65, -14.91)
#
# Processing object in (-4.58, 1.65, -14.72)
#
# Processing object in (-26.17, 1.65, -46.06)
#
# Processing object in (-7.55, 1.65, -9.31)
#
# Processing object in (-3.09, 1.65, -7.05)
#
# Processing object in (-42.35, 1.65, 73.78)
#
# Processing object in (-1.39, 1.65, 10.43)
#
# Processing object in (6.2, 1.65, 23.27)
#
# Processing object in (-4.57, 1.65, 45.54)
#
# Processing object in (-3.78, 1.65, 9.59)
#
# Processing object in (-5.54, 1.65, 7.17)
#
# Processing object in (1.48, 1.65, 5.98)
#
# Processing object in (-1.35, 1.65, -8.39)
#
# Processing object in (-1.78, 1.65, 21.99)
#
# Processing object in (0.89, 1.65, 5.89)
#
# Processing object in (-1.39, 1.65, 31.21)
#
# Processing object in (-3.62, 1.65, 5.89)
#
# Processing object in (3.33, 1.65, 5.89)
#
# Processing object in (12.0, 1.65, 73.72)
#
# Processing object in (0.4, 1.65, -8.57)
#
# Processing object in (-2.78, 1.65, -11.92)
#
# Processing object in (-3.47, 1.65, -25.96)
#
# Processing object in (0.3, 1.65, 10.08)
#
# Processing object in (20.86, 1.65, 30.4)
#
# Processing object in (-3.39, 1.65, -8.16)
#
# Processing object in (0.54, 1.65, 5.98)
#
# Processing object in (9.69, 1.65, 31.2)
#
# Processing object in (5.05, 1.65, 15.43)
#
# Processing object in (4.75, 1.65, -22.96)
#
# Processing object in (1.95, 1.65, 39.49)
#
# Processing object in (0.25, 1.65, 5.89)
#
# Processing object in (1.43, 1.65, 5.89)
#
# Processing object in (4.19, 1.65, -10.1)
#
# Processing object in (-2.02, 1.65, 5.89)
#
# Processing object in (-4.05, 1.65, -7.27)
#
# Processing object in (43.72, 1.65, 90.5)
#
# Processing object in (-2.33, 1.65, -14.2)
#
# Processing object in (-10.25, 1.65, -15.91)
#
# Processing object in (-45.01, 1.65, 59.13)
#
# Processing object in (-15.51, 1.65, 38.23)
#
# Processing object in (-4.13, 1.65, -13.1)
#
# Processing object in (-0.44, 1.65, -7.69)
#
# Processing object in (-3.73, 1.65, 5.89)
#
# Processing object in (-3.6, 1.65, 45.54)
#
# Processing object in (3.3, 1.65, 11.11)
#
# Processing object in (-16.89, 1.65, 37.05)
#
# Processing object in (15.87, 1.65, 19.79)
#
# Processing object in (5.21, 1.65, 23.74)
#
# Processing object in (-4.38, 1.65, 6.26)
#
# Processing object in (0.26, 1.65, 5.89)
#
# Processing object in (5.32, 1.65, 11.43)
#
# Processing object in (-5.44, 1.65, -7.09)
#
# Processing object in (7.74, 1.65, 28.93)
#
# Processing object in (16.63, 1.65, 24.22)
#
# Processing object in (-0.04, 1.65, 5.89)
#
# Processing object in (-4.89, 1.65, -17.04)
#
# Processing object in (1.73, 1.65, 5.98)
#
# Processing object in (-2.69, 1.65, -9.03)
#
# Processing object in (16.27, 1.65, -28.44)
#
# Processing object in (0.53, 1.65, -8.57)
#
# Processing object in (5.06, 1.65, 5.89)
#
# Processing object in (9.74, 1.65, 16.5)
#
# Processing object in (3.99, 1.65, -17.55)
#
# Processing object in (-3.7, 1.65, 28.94)
#
# Processing object in (5.05, 1.65, 37.03)
#
# Processing object in (-1.8, 1.65, 5.89)
#
# Processing object in (2.97, 1.65, 12.64)
#
# Processing object in (4.19, 1.65, 5.89)
#
# Processing object in (-2.56, 1.65, 5.89)
#
# Processing object in (-4.1, 1.65, 10.81)
#
# Processing object in (-2.4, 1.65, 20.13)
#
# Processing object in (45.87, 1.65, 78.55)
#
# Processing object in (4.02, 1.65, 43.85)
#
# Processing object in (-3.69, 1.65, -14.2)
#
# Processing object in (5.61, 1.65, -6.89)
#
# Processing object in (0.94, 1.65, 5.89)
#
# Processing object in (-6.71, 1.65, 10.52)
#
# Processing object in (-4.93, 1.65, -19.89)
#
# Processing object in (1.64, 1.65, 6.76)
#
# Processing object in (1.85, 1.65, 5.89)
#
# Processing object in (0.22, 1.65, -8.51)
#
# Processing object in (-133.82, 1.65, 231.74)
#
# Processing object in (5.4, 1.65, -23.88)
#
# Processing object in (-3.72, 1.65, -9.61)
#
# Processing object in (4.95, 1.65, 6.68)
#
# Processing object in (-2.82, 1.65, 24.23)
#
# Processing object in (-7.79, 1.65, -13.4)
#
# Processing object in (14.36, 1.65, 34.86)
#
# Processing object in (-6.59, 1.65, -13.55)
#
# Processing object in (10.79, 1.65, 32.93)
#
# Processing object in (-5.66, 1.65, -11.69)
#
# Processing object in (8.47, 1.65, -12.68)
#
# Processing object in (-2.55, 1.65, -11.25)
#
# Processing object in (-5.81, 1.65, 8.75)
#
# Processing object in (2.33, 1.65, 33.87)
#
# Processing object in (5.88, 1.65, 26.96)
#
# Processing object in (-3.92, 1.65, -7.09)
#
# Processing object in (5.48, 1.65, 19.15)
#
# Processing object in (-5.05, 1.65, -6.89)
#
# Processing object in (8.66, 1.65, 13.35)
#
# Processing object in (2.67, 1.65, 90.55)
#
# Processing object in (3.74, 1.65, -18.36)
#
# Processing object in (2.78, 1.65, 6.92)
#
# Processing object in (-5.33, 1.65, -46.05)
#
# Processing object in (116.37, 1.65, 230.95)
#
# Processing object in (5.26, 1.65, -14.03)
#
# Processing object in (-186.38, 1.65, 1040.76)
#
# Processing object in (8.73, 1.65, 25.25)
#
# Processing object in (-1.47, 1.65, 5.89)
#
# Processing object in (-5.97, 1.65, -13.71)
#
# Processing object in (-0.32, 1.65, 8.32)
#
# Processing object in (-7.07, 1.65, -21.7)
#
# Processing object in (-17.06, 1.65, 39.5)
#
# Processing object in (13.56, 1.65, -16.34)
#
# Processing object in (21.9, 1.65, 45.52)
#
# Processing object in (-7.57, 1.65, -11.57)
#
# Processing object in (7.82, 1.65, 24.22)
#
# Processing object in (-0.66, 1.65, 14.85)
#
# Processing object in (23.52, 1.65, -29.14)
#
# Processing object in (15.56, 1.65, 35.91)
#
# Processing object in (0.87, 1.65, -8.33)
#
# Processing object in (15.33, 1.65, 26.96)
#
# Processing object in (-9.0, 1.65, 13.21)
#
# Processing object in (-4.07, 1.65, 7.34)
#
# Processing object in (12.74, 1.65, 17.21)
#
# Processing object in (6.9, 1.65, 25.8)
#
# Processing object in (-22.25, 1.65, -44.34)
#
# Processing object in (-2.15, 1.65, 5.89)
#
# Processing object in (-1.21, 1.65, 5.89)
#
# Processing object in (-1.03, 1.65, 6.07)
#
# Processing object in (26.32, 1.65, 34.85)
#
# Processing object in (-0.65, 1.65, 13.82)
#
# Processing object in (1.2, 1.65, 40.85)
#
# Processing object in (-7.79, 1.65, -10.37)
#
# Processing object in (28.35, 1.65, 43.83)
#
# Processing object in (4.17, 1.65, 5.89)
#
# Processing object in (2.72, 1.65, 8.26)
#
# Processing object in (-4.34, 1.65, 24.73)
#
# Processing object in (0.13, 1.65, -8.7)
#
# Processing object in (13.1, 1.65, 97.99)
#
# Processing object in (-1.39, 1.65, -12.29)
#
# Processing object in (-12.58, 1.65, 166.61)
#
# Processing object in (1.86, 1.65, 5.89)
#
# Processing object in (1.79, 1.65, 5.89)
#
# Processing object in (0.58, 1.65, -9.1)
#
# Processing object in (3.98, 1.65, 5.95)
#
# Processing object in (26.49, 1.65, 39.47)
#
# Processing object in (-8.14, 1.65, 11.22)
#
# Processing object in (-112.13, 1.65, -151.8)
#
# Processing object in (1.19, 1.65, 5.89)
#
# Processing object in (2.22, 1.65, 6.01)
#
# Processing object in (-66.89, 1.65, -100.51)
#
# Processing object in (18.22, 1.65, 32.04)
#
# Processing object in (-2.03, 1.65, -20.58)
#
# Processing object in (-0.02, 1.65, 5.89)
#
# Processing object in (22.09, 1.65, -37.37)
#
# Processing object in (-1.54, 1.65, -20.94)
#
# Processing object in (5.95, 1.65, 19.47)
#
# Processing object in (-4.25, 1.65, -31.45)
#
# Processing object in (1.54, 1.65, 5.89)
#
# Processing object in (-81.24, 1.65, 106.93)
#
# Processing object in (-3.33, 1.65, 6.01)
#
# Processing object in (-1.51, 1.65, 7.88)
#
# Processing object in (-0.91, 1.65, 6.04)
#
# Processing object in (-4.43, 1.65, 5.92)
#
# Processing object in (-8.14, 1.65, -17.04)
#
# Processing object in (-6.62, 1.65, 27.6)
#
# Processing object in (-7.05, 1.65, -13.25)
#
# Processing object in (-4.27, 1.65, 5.89)
#
# Processing object in (83.45, 1.65, 193.46)
#
# Processing object in (-4.05, 1.65, -8.51)
#
# Processing object in (1.19, 1.65, -10.1)
#
# Processing object in (1.89, 1.65, -7.59)
#
# Processing object in (-4.81, 1.65, 6.61)
#
# Processing object in (-19.44, 1.65, 193.74)
#
# Processing object in (35.07, 1.65, 43.83)
#
# Processing object in (-15.0, 1.65, 32.94)
#
# Processing object in (1.66, 1.65, 51.43)
#
# Processing object in (41.46, 1.65, -70.61)
#
# Processing object in (-5.83, 1.65, -23.41)
#
# Processing object in (-3.44, 1.65, 28.94)
#
# Processing object in (-8.2, 1.65, 12.92)
#
# Processing object in (2.52, 1.65, -9.93)
#
# Processing object in (-7.22, 1.65, 11.32)
#
# Processing object in (-1.38, 1.65, 11.54)
#
# Processing object in (4.27, 1.65, -20.94)
#
# Processing object in (2.9, 1.65, 6.1)
#
# Processing object in (31.65, 1.65, 47.32)
#
# Processing object in (14.58, 1.65, -24.37)
#
# Processing object in (17.75, 1.65, 40.83)
#
# Processing object in (15.24, 1.65, 25.79)
#
# Processing object in (-5.93, 1.65, -18.36)
#
# Processing object in (-15.09, 1.65, -29.14)
#
# Processing object in (3.48, 1.65, -15.1)
#
# Processing object in (-6.04, 1.65, 15.43)
#
# Processing object in (26.4, 1.65, 49.28)
#
# Processing object in (5.03, 1.65, 17.47)
#
# Processing object in (-5.03, 1.65, -7.09)
#
# Processing object in (0.05, 1.65, -8.45)
#
# Processing object in (-13.34, 1.65, 32.94)
#
# Processing object in (-2.79, 1.65, 47.35)
#
# Processing object in (22.53, 1.65, 35.9)
#
# Processing object in (-7.39, 1.65, -15.7)
#
# Processing object in (-3.17, 1.65, -14.2)
#
# Processing object in (-4.64, 1.65, -17.29)
#
# Processing object in (-8.18, 1.65, -70.65)
#
# Processing object in (12.92, 1.65, 34.86)
#
# Processing object in (-2.46, 1.65, 5.89)
#
# Processing object in (-10.8, 1.65, 17.73)
#
# Processing object in (-8.27, 1.65, 12.13)
#
# Processing object in (-3.26, 1.65, 5.89)
#
# Processing object in (2.09, 1.65, -9.77)
#
# Processing object in (-15.77, 1.65, -63.16)
#
# Processing object in (-3.76, 1.65, 38.23)
#
# Processing object in (-6.57, 1.65, -12.55)
#
# Processing object in (-6.81, 1.65, -49.91)
#
# Processing object in (2.54, 1.65, -7.14)
#
# Processing object in (37.11, 1.65, 97.96)
#
# Processing object in (-7.36, 1.65, 29.66)
#
# Processing object in (11.52, 1.65, 39.48)
#
# Processing object in (-4.05, 1.65, 6.54)
#
# Processing object in (-4.39, 1.65, 6.04)
#
# Processing object in (5.19, 1.65, 8.03)
#
# Processing object in (5.57, 1.65, 14.85)
#
# Processing object in (-6.52, 1.65, -20.58)
#
# Processing object in (1.63, 1.65, 9.29)
#
# Processing object in (4.22, 1.65, 84.15)
#
# Processing object in (0.68, 1.65, 7.53)
#
# Processing object in (10.25, 1.65, 24.72)
#
# Processing object in (-14.64, 1.65, 53.77)
#
# Processing object in (1.11, 1.65, 6.96)
#
# Processing object in (-1.76, 1.65, 21.2)
#
# Processing object in (-6.25, 1.65, -16.8)
#
# Processing object in (5.38, 1.65, 14.49)
#
# Processing object in (3.73, 1.65, -12.04)
#
# Processing object in (6.86, 1.65, 28.24)
#
# Processing object in (-14.01, 1.65, -22.53)
#
# Processing object in (-3.97, 1.65, -54.48)
#
# Processing object in (11.41, 1.65, 26.36)
#
# Processing object in (-3.01, 1.65, 5.89)
#
# Processing object in (0.98, 1.65, 7.43)
#
# Processing object in (14.35, 1.65, 49.29)
#
# Processing object in (-3.89, 1.65, -7.36)
#
# Processing object in (-2.01, 1.65, -27.78)
#
# Processing object in (1.42, 1.65, 9.36)
#
# Processing object in (6.27, 1.65, -7.59)
#
# Processing object in (112.4, 1.65, 193.38)
#
# Processing object in (-19.53, 1.65, 26.38)
#
# Processing object in (0.24, 1.65, -9.31)
#
# Processing object in (6.2, 1.65, 12.25)
#
# Processing object in (-0.45, 1.65, -20.58)
#
# Processing object in (-4.61, 1.65, 7.72)
#
# Processing object in (-1.1, 1.65, 5.89)
#
# Processing object in (-12.57, 1.65, 28.25)
#
# Processing object in (11.83, 1.65, -21.7)
#
# Processing object in (-17.23, 1.65, -24.88)
#
# Processing object in (-11.86, 1.65, -34.16)
#
# Processing object in (-2.97, 1.65, -25.96)
#
# Processing object in (-8.9, 1.65, 13.99)
#
# Processing object in (21.34, 1.65, 28.92)
#
# Processing object in (7.01, 1.65, 98.0)
#
# Processing object in (4.7, 1.65, 15.43)
#
# Processing object in (-1.26, 1.65, 20.83)
#
# Processing object in (3.78, 1.65, 7.43)
#
# Processing object in (-3.52, 1.65, 5.89)
#
# Processing object in (-9.89, 1.65, 20.48)
#
# Processing object in (1.59, 1.65, 6.16)
#
# Processing object in (4.15, 1.65, 14.67)
#
# Processing object in (10.36, 1.65, 90.54)
#
# Processing object in (-17.9, 1.65, 22.84)
#
# Processing object in (1.16, 1.65, 5.89)
#
# Processing object in (13.98, 1.65, 78.58)
#
# Processing object in (-8.21, 1.65, -20.58)
#
# Processing object in (6.79, 1.65, 26.96)
#
# Processing object in (-3.31, 1.65, 6.92)
#
# Processing object in (-68.65, 1.65, 84.24)
#
# Processing object in (12.99, 1.65, 18.27)
#
# Processing object in (2.09, 1.65, 6.04)
#
# Processing object in (-11.47, 1.65, -19.89)
#
# Processing object in (-21.9, 1.65, -309.05)
#
# Processing object in (23.22, 1.65, 28.92)
#
# Processing object in (-8.86, 1.65, -19.56)
#
# Processing object in (-0.7, 1.65, 19.47)
#
# Processing object in (-10.07, 1.65, 16.98)
#
# Processing object in (-3.61, 1.65, 5.89)
#
# Processing object in (-19.02, 1.65, 39.5)
#
# Processing object in (-7.63, 1.65, -30.64)
#
# Processing object in (3.79, 1.65, 51.43)
#
# Processing object in (-3.93, 1.65, -9.54)
#
# Processing object in (12.35, 1.65, 78.59)
#
# Processing object in (-5.26, 1.65, 19.16)
#
# Processing object in (-28.96, 1.65, -66.7)
#
# Processing object in (0.12, 1.65, 9.99)
#
# Processing object in (0.98, 1.65, -8.22)
#
# Processing object in (9.82, 1.65, -15.29)
#
# Processing object in (-1.54, 1.65, -6.89)
#
# Processing object in (19.24, 1.65, 37.02)
#
# Processing object in (-1.02, 1.65, -20.58)
#
# Processing object in (10.33, 1.65, 26.36)
#
# Processing object in (6.27, 1.65, 10.61)
#
# Processing object in (11.18, 1.65, 17.73)
#
# Processing object in (4.31, 1.65, 5.89)
#
# Processing object in (10.11, 1.65, 13.66)
#
# Processing object in (18.25, 1.65, 38.21)
#
# Processing object in (11.15, 1.65, 18.85)
#
# Processing object in (21.55, 1.65, 38.21)
#
# Processing object in (1.31, 1.65, 5.89)
#
# Processing object in (0.23, 1.65, 7.88)
#
# Processing object in (-5.95, 1.65, 11.32)
#
# Processing object in (46.49, 1.65, 73.68)
#
# Processing object in (-2.28, 1.65, 19.47)
#
# Processing object in (6.31, 1.65, 13.82)
#
# Processing object in (18.91, 1.65, 34.85)
#
# Processing object in (-278.07, 1.65, -644.66)
#
# Processing object in (23.96, 1.65, -308.87)
#
# Processing object in (7.34, 1.65, 53.75)
#
# Processing object in (-4.95, 1.65, -52.1)
#
# Processing object in (-0.3, 1.65, 59.09)
#
# Processing object in (-6.2, 1.65, 11.01)
#
# Processing object in (-9.66, 1.65, -20.23)
#
# Processing object in (-17.15, 1.65, -33.21)
#
# Processing object in (0.29, 1.65, 6.01)
#
# Processing object in (4.54, 1.65, 6.16)
#
# Processing object in (12.44, 1.65, -21.7)
#
# Processing object in (-5.8, 1.65, 47.35)
#
# Processing object in (60.83, 1.65, 90.48)
#
# Processing object in (1.19, 1.65, 5.89)
#
# Processing object in (12.74, 1.65, 47.33)
#
# Processing object in (1.78, 1.65, 8.94)
#
# Processing object in (2.21, 1.65, 9.08)
#
# Processing object in (-10.62, 1.65, 16.74)
#
# Processing object in (12.38, 1.65, 28.93)
#
# Processing object in (-11.41, 1.65, -28.45)
#
# Processing object in (-0.32, 1.65, -6.89)
#
# Processing object in (-2.67, 1.65, -12.04)
#
# Processing object in (3.77, 1.65, -7.05)
#
# Processing object in (-3.69, 1.65, 6.23)
#
# Processing object in (-5.66, 1.65, -6.89)
#
# Processing object in (-4.55, 1.65, -10.37)
#
# Processing object in (-0.61, 1.65, 5.89)
#
# Processing object in (0.35, 1.65, 7.48)
#
# Processing object in (9.52, 1.65, 25.79)
#
# Processing object in (8.6, 1.65, -37.37)
#
# Processing object in (-5.38, 1.65, 21.99)
#
# Processing object in (-4.21, 1.65, 29.66)
#
# Processing object in (6.93, 1.65, 8.62)
#
# Processing object in (2.69, 1.65, 5.89)
#
# Processing object in (-7.08, 1.65, -92.63)
#
# Processing object in (-1.07, 1.65, -46.05)
#
# Processing object in (2.82, 1.65, 6.01)
#
# Processing object in (-1.56, 1.65, 6.96)
#
# Processing object in (-2.12, 1.65, -6.89)
#
# Processing object in (-4.15, 1.65, 5.89)
#
# Processing object in (-10.68, 1.65, 19.16)
#
# Processing object in (-5.18, 1.65, 11.77)
#
# Processing object in (7.0, 1.65, 11.89)
#
# Processing object in (-24.0, 1.65, -44.34)
#
# Processing object in (34.05, 1.65, 49.28)
#
# Processing object in (-41.13, 1.65, 287.26)
#
# Processing object in (-11.95, 1.65, -24.88)
#
# Processing object in (12.26, 1.65, 26.96)
#
# Processing object in (-2.15, 1.65, -6.89)
#
# Processing object in (-5.46, 1.65, -10.37)
#
# Processing object in (91.68, 1.65, 145.95)
#
# Processing object in (3.84, 1.65, 13.5)
#
# Processing object in (6.63, 1.65, 13.82)
#
# Processing object in (-2.68, 1.65, -13.1)
#
# Processing object in (-1.26, 1.65, 7.43)
#
# Processing object in (4.38, 1.65, -9.54)
#
# Processing object in (6.07, 1.65, -12.29)
#
# Processing object in (-2.05, 1.65, 21.2)
#
# Processing object in (14.79, 1.65, 42.29)
#
# Processing object in (-12.84, 1.65, -17.81)
#
# Processing object in (-4.94, 1.65, 7.72)
#
# Processing object in (-1.22, 1.65, 35.92)
#
# Processing object in (12.23, 1.65, -59.96)
#
# Processing object in (6.39, 1.65, 18.56)
#
# Processing object in (-12.11, 1.65, -20.94)
#
# Processing object in (-18.47, 1.65, -39.89)
#
# Processing object in (-20.31, 1.65, -75.11)
#
# Processing object in (22.87, 1.65, -37.37)
#
# Processing object in (-24.6, 1.65, 31.22)
#
# Processing object in (18.36, 1.65, 47.33)
#
# Processing object in (16.23, 1.65, -28.44)
#
# Processing object in (-2.36, 1.65, -11.46)
#
# Processing object in (8.92, 1.65, 45.53)
#
# Processing object in (97.62, 1.65, 145.93)
#
# Processing object in (-13.12, 1.65, -22.96)
#
# Processing object in (-31.65, 1.65, -109.73)
#
# Processing object in (10.35, 1.65, -41.26)
#
# Processing object in (26.65, 1.65, 47.32)
#
# Processing object in (0.19, 1.65, 7.43)
#
# Processing object in (-2.93, 1.65, 7.34)
#
# Processing object in (-5.77, 1.65, 78.61)
#
# Processing object in (-20.36, 1.65, 45.55)
#
# Processing object in (-3.77, 1.65, -15.9)
#
# Processing object in (3.43, 1.65, 5.89)
#
# Processing object in (-5.85, 1.65, -203.41)
#
# Processing object in (0.41, 1.65, -9.17)
#
# Processing object in (8.5, 1.65, -41.26)
#
# Processing object in (-1.08, 1.65, 5.89)
#
# Processing object in (15.0, 1.65, 59.08)
#
# Processing object in (45.49, 1.65, -80.11)
#
# Processing object in (14.87, 1.65, -28.44)
#
# Processing object in (-5.44, 1.65, -12.04)
#
# Processing object in (-2.56, 1.65, -34.16)
#
# Processing object in (8.63, 1.65, 17.99)
#
# Processing object in (-8.43, 1.65, -37.38)
#
# Processing object in (-1.89, 1.65, 6.01)
#
# Processing object in (16.28, 1.65, 31.2)
#
# Processing object in (-1.31, 1.65, 5.89)
#
# Processing object in (-5.29, 1.65, -19.56)
#
# Processing object in (-61.3, 1.65, -173.84)
#
# Processing object in (5.16, 1.65, -63.14)
#
# Processing object in (-11.42, 1.65, 193.72)
#
# Processing object in (-0.72, 1.65, -6.89)
#
# Processing object in (-306.55, 1.65, 556.84)
#
# Processing object in (-2.28, 1.65, -10.94)
#
# Processing object in (-0.72, 1.65, -28.45)
#
# Processing object in (-3.19, 1.65, 5.95)
#
# Processing object in (9.85, 1.65, 106.79)
#
# Processing object in (-2.51, 1.65, 5.89)
#
# Processing object in (4.46, 1.65, 5.89)
#
# Processing object in (-9.78, 1.65, 15.44)
#
# Processing object in (-3.28, 1.65, 23.28)
#
# Processing object in (-1879.02, 1.65, 8313.16)
#
# Processing object in (6.54, 1.65, 35.91)
#
# Processing object in (3.82, 1.65, -9.17)
#
# Processing object in (-14.0, 1.65, -26.55)
#
# Processing object in (-0.44, 1.65, 5.89)
#
# Processing object in (11.81, 1.65, 21.58)
#
# Processing object in (5.46, 1.65, -6.89)
#
# Processing object in (-1.98, 1.65, -7.4)
#
# Processing object in (5.41, 1.65, 11.77)
#
# Processing object in (-4.96, 1.65, -29.87)
#
# Processing object in (15.77, 1.65, 32.93)
#
# Processing object in (13.5, 1.65, 24.72)
#
# Processing object in (1.11, 1.65, -6.89)
#
# Processing object in (-1.16, 1.65, 5.89)
#
# Processing object in (2.08, 1.65, 5.89)
#
# Processing object in (5.43, 1.65, 6.76)
#
# Processing object in (-0.67, 1.65, -10.1)
#
# Processing object in (-20.99, 1.65, 49.32)
#
# Processing object in (4.64, 1.65, -9.77)
#
# Processing object in (-12.48, 1.65, 51.44)
#
# Processing object in (3.27, 1.65, 7.77)
#
# Processing object in (1.16, 1.65, 6.43)
#
# Processing object in (38.53, 1.65, -70.61)
#
# Processing object in (20.54, 1.65, 62.16)
#
# Processing object in (3.24, 1.65, 13.35)
#
# Processing object in (-8.55, 1.65, -26.54)
#
# Processing object in (92.61, 1.65, 129.99)
#
# Processing object in (-0.13, 1.65, -8.33)
#
# Processing object in (-8.14, 1.65, 29.66)
#
# Processing object in (-3.07, 1.65, 25.8)
#
# Processing object in (2.56, 1.65, -9.24)
#
# Processing object in (-10.31, 1.65, 18.0)
#
# Processing object in (25.69, 1.65, 43.84)
#
# Processing object in (15.75, 1.65, -63.14)
#
# Processing object in (12.35, 1.65, 25.79)
#
# Processing object in (90.1, 1.65, 129.99)
#
# Processing object in (-3.05, 1.65, -13.4)
#
# Processing object in (-4.62, 1.65, 8.75)
#
# Processing object in (-3.02, 1.65, -6.89)
#
# Processing object in (-9.2, 1.65, 15.05)
#
# Processing object in (3.73, 1.65, -21.31)
#
# Processing object in (-13.23, 1.65, -19.25)
#
# Processing object in (-23.52, 1.65, -151.64)
#
# Processing object in (-71.74, 1.65, 378.7)
#
# Processing object in (20.15, 1.65, -38.58)
#
# Processing object in (-3.26, 1.65, 35.92)
#
# Processing object in (-1.08, 1.65, -11.8)
#
# Processing object in (3.01, 1.65, 5.89)
#
# Processing object in (-12.25, 1.65, 25.26)
#
# Processing object in (-18.38, 1.65, -42.75)
#
# Processing object in (-14.2, 1.65, -29.14)
#
# Processing object in (-0.01, 1.65, -6.89)
#
# Processing object in (-0.08, 1.65, -18.08)
#
# Processing object in (-0.11, 1.65, 5.89)
#
# Processing object in (-10.11, 1.65, 14.86)
#
# Processing object in (-0.17, 1.65, -6.89)
#
# Processing object in (-6.92, 1.65, -8.39)
#
# Processing object in (8.62, 1.65, 11.32)
#
# Processing object in (10.65, 1.65, 23.27)
#
# Processing object in (-32.91, 1.65, -46.06)
#
# Processing object in (6.62, 1.65, -44.33)
#
# Processing object in (-4.53, 1.65, 5.89)
#
# Processing object in (1.4, 1.65, 6.72)
#
# Processing object in (8.79, 1.65, 13.98)
#
# Processing object in (7.18, 1.65, 14.85)
#
# Processing object in (17.79, 1.65, -173.68)
#
# Processing object in (2.56, 1.65, 11.65)
#
# Processing object in (-7.01, 1.65, 31.21)
#
# Processing object in (1.09, 1.65, -6.89)
#
# Processing object in (-3.75, 1.65, 5.89)
#
# Processing object in (-2.43, 1.65, 5.89)
#
# Processing object in (8.51, 1.65, 10.61)
#
# Processing object in (-33.28, 1.65, 65.64)
#
# Processing object in (11.21, 1.65, -41.26)
#
# Processing object in (27.86, 1.65, 90.52)
#
# Processing object in (-4.82, 1.65, -21.7)
#
# Processing object in (-2.84, 1.65, 16.73)
#
# Processing object in (2.86, 1.65, 6.33)
#
# Processing object in (-0.16, 1.65, 14.32)
#
# Processing object in (-14.6, 1.65, 53.77)
#
# Processing object in (8.87, 1.65, -245.28)
#
# Processing object in (5.56, 1.65, 7.53)
#
# Processing object in (5.33, 1.65, -6.89)
#
# Processing object in (8.91, 1.65, 12.51)
#
# Processing object in (8.55, 1.65, 14.49)
#
# Processing object in (4.79, 1.65, 6.01)
#
# Processing object in (4.75, 1.65, 8.03)
#
# Processing object in (-3.11, 1.65, -20.58)
#
# Processing object in (-0.87, 1.65, 14.85)
#
# Processing object in (-1.83, 1.65, -7.45)
#
# Processing object in (-17.98, 1.65, 42.31)
#
# Processing object in (-5.93, 1.65, -13.25)
#
# Processing object in (-154.9, 1.65, -245.77)
#
# Processing object in (-289.06, 1.65, 379.81)
#
# Processing object in (-23.59, 1.65, 193.75)
#
# Processing object in (30.15, 1.65, 42.28)
#
# Processing object in (-2.04, 1.65, -17.55)
#
# Processing object in (-4.45, 1.65, 8.04)
#
# Processing object in (4.88, 1.65, 18.56)
#
# Processing object in (3.2, 1.65, 6.33)
#
# Processing object in (22.9, 1.65, -100.41)
#
# Processing object in (154.93, 1.65, -203.01)
#
# Processing object in (26.16, 1.65, 97.97)
#
# Processing object in (9.15, 1.65, -12.68)
#
# Processing object in (1.33, 1.65, 5.89)
#
# Processing object in (1.16, 1.65, 6.07)
#
# Processing object in (0.93, 1.65, -11.69)
#
# Processing object in (-3.33, 1.65, -12.82)
#
# Processing object in (1.7, 1.65, -134.47)
#
# Processing object in (-10.4, 1.65, -120.84)
#
# Processing object in (-30.85, 1.65, 43.88)
#
# Processing object in (-10.5, 1.65, -21.71)
#
# Processing object in (-7.17, 1.65, -9.61)
#
# Processing object in (37.28, 1.65, 49.27)
#
# Processing object in (70.38, 1.65, 90.46)
#
# Processing object in (-1.42, 1.65, 9.83)
#
# Processing object in (4.52, 1.65, -7.05)
#
# Processing object in (-3.61, 1.65, -15.7)
#
# Processing object in (1.41, 1.65, 5.95)
#
# Processing object in (-78.85, 1.65, 287.41)
#
# Processing object in (16.24, 1.65, 21.98)
#
# Processing object in (-2.25, 1.65, 5.89)
#
# Processing object in (-6.55, 1.65, -18.94)
#
# Processing object in (-10.94, 1.65, -25.41)
#
# Processing object in (1734.3, 1.65, 7931.89)
#
# Processing object in (-16.0, 1.65, 84.18)
#
# Processing object in (5.88, 1.65, 13.5)
#
# Processing object in (3.54, 1.65, 18.27)
#
# Processing object in (3.29, 1.65, 6.61)
#
# Processing object in (10.4, 1.65, 25.25)
#
# Processing object in (0.43, 1.65, -6.89)
#
# Processing object in (-7.77, 1.65, 53.76)
#
# Processing object in (-27.51, 1.65, 37.05)
#
# Processing object in (3.74, 1.65, 5.89)
#
# Processing object in (-10.08, 1.65, -57.1)
#
# Processing object in (1.07, 1.65, 5.89)
#
# Processing object in (-0.53, 1.65, 5.89)
#
# Processing object in (5.86, 1.65, 9.08)
#
# Processing object in (-1.18, 1.65, -22.96)
#
# Processing object in (-22.1, 1.65, -109.72)
#
# Processing object in (-1.17, 1.65, 14.67)
#
# Processing object in (-9.07, 1.65, 15.85)
#
# Processing object in (3.27, 1.65, -9.85)
#
# Processing object in (0.74, 1.65, -6.89)
#
# Processing object in (0.29, 1.65, -6.89)
#
# Processing object in (-5.4, 1.65, -12.42)
#
# Processing object in (3.65, 1.65, -19.56)
#
# Processing object in (1.91, 1.65, -6.97)
#
# Processing object in (4.06, 1.65, 6.07)
#
# Processing object in (3.67, 1.65, 5.89)
#
# Processing object in (-7.0, 1.65, 14.86)
#
# Processing object in (4.45, 1.65, -6.89)
#
# Processing object in (-691.02, 1.65, 1047.64)
#
# Processing object in (7.29, 1.65, 9.83)
#
# Processing object in (-0.54, 1.65, 14.67)
#
# Processing object in (6.23, 1.65, -59.96)
#
# Processing object in (-52.0, 1.65, 117.42)
#
# Processing object in (-11.41, 1.65, -35.17)
#
# Processing object in (-48.62, 1.65, 73.79)
#
# Processing object in (0.03, 1.65, -9.54)
#
# Processing object in (-0.09, 1.65, 5.89)
#
# Processing object in (-0.96, 1.65, -34.16)
#
# Processing object in (-3.49, 1.65, -9.46)
#
# Processing object in (-23.83, 1.65, -203.45)
#
# Processing object in (16.45, 1.65, 34.85)
#
# Processing object in (-2.05, 1.65, -14.2)
#
# Processing object in (-34.64, 1.65, -52.11)
#
# Processing object in (-3.62, 1.65, 7.48)
#
# Processing object in (-2.77, 1.65, -17.81)
#
# Processing object in (0.13, 1.65, -6.89)
#
# Processing object in (6.62, 1.65, -11.14)
#
# Processing object in (-7.05, 1.65, -16.34)
#
# Processing object in (-26.3, 1.65, 62.2)
#
# Processing object in (9.96, 1.65, 13.98)
#
# Processing object in (1.81, 1.65, -52.09)
#
# Processing object in (4.69, 1.65, 5.89)
#
# Processing object in (2.84, 1.65, 5.89)
#
# Processing object in (0.04, 1.65, 6.04)
#
# Processing object in (-1.19, 1.65, 9.91)
#
# Processing object in (-39.78, 1.65, -92.67)
#
# Processing object in (-12.58, 1.65, 21.21)
#
# Processing object in (-1.35, 1.65, -28.45)
#
# Processing object in (-23.15, 1.65, -245.37)
